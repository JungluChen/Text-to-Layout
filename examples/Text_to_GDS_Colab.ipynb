# %% [markdown]
# # Text-to-GDS Colab
# Install the package and run local deterministic verification.

# %%
# !pip install git+https://github.com/JungluChen/Text-to-Layout.git
from text_to_gds.scientific_verification import confidence_interval
confidence_interval(6.0, 0.1)
